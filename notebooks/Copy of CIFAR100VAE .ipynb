# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image
from torchvision.datasets import MNIST, FashionMNIST, CIFAR10, STL10, CIFAR100
import os
import pickle
import zipfile
import datetime
import torch.utils.data as tud

# %%
torch.manual_seed(4)
np.random.seed(4)

# %% [markdown]
# # Data Preparation:

# %%
mean,std = (0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)
data_transform = transforms.Compose([ transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean,std),
                transforms.Resize((96,96))
        ])

# %%
train = CIFAR100(root='./data', train=True,download=True, transform=data_transform)
test = torchvision.datasets.CIFAR100(root='./data', train=False,download=True, transform=data_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
test
# Out:
# Dataset CIFAR100
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.5071, 0.4867, 0.4408), std=(0.2675, 0.2565, 0.2761))
#                Resize(size=(96, 96), interpolation=bilinear, max_size=None, antialias=None)
#            )

# %%
train_loader = torch.utils.data.DataLoader(train, batch_size=50000, shuffle=False, num_workers=0)

# %%
data, labels= next(iter(train_loader))

# %% [markdown]
# ## Using 500 labled data for 1% and 5000 labeled data for 10% case

# %%
#keep 1500 as labeled data
np.random.seed(5)
labeled_ind = np.random.choice(50000,7000, replace = False)

# %%
unlabeled_ind = np.setdiff1d(list(range(50000)), labeled_ind)

# %%
unlabeled_ind.shape
# Out:
# (43000,)

# %%
labels = labels.numpy()

# %%
#unlabeled data coded as 10
np.put(labels,list(unlabeled_ind),100)

# %%
#make 0.3 of the labeled data dev set, dev set is made sure to have balanced labels
np.random.seed(5)
dev_ind = labeled_ind[np.random.choice(7000,2000, replace = False)]

# %%
train_ind = np.setdiff1d(list(range(50000)), dev_ind)

# %%
#450 labeled data for dev set, 1050 labeled data + 6500 unlabeled data for training set
len(dev_ind), len(train_ind)
# Out:
# (2000, 48000)

# %%
#prepare dataloader for pytorch
class TorchInputData(tud.Dataset):
    """
    A simple inheretance of torch.DataSet to enable using our customized DogBreed dataset in torch
    """
    def __init__(self, X, Y, transform=None):
        """
        X: a list of numpy images 
        Y: a list of labels coded using 0-9 
        """        
        self.X = X
        self.Y = Y 

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.Y[idx]

        return x, y

# %%
images_train = [data[i] for i in train_ind]
trainset = TorchInputData(images_train, labels[train_ind])
train_loader = tud.DataLoader(trainset, batch_size=128, shuffle=True)

# %%
len(trainset)
# Out:
# 48000

# %%
images_dev = [data[i] for i in dev_ind]
devset = TorchInputData(images_dev, labels[dev_ind])
dev_loader = tud.DataLoader(devset, batch_size=128, shuffle=True)

# %%
len(devset)
# Out:
# 2000

# %% [markdown]
# # M2 Model:

# %%
#import nn.module for M2 and CNN classifier
from m2_cifar100_cuda import M2,Classifier

# %%
from torch.nn.utils import weight_norm

class Discriminator(nn.Module):
        """docstring for Discriminator"""
        def __init__(self,num_classes):
            super(Discriminator, self).__init__()
            self.net = nn.Sequential(
                    weight_norm(nn.Conv2d(3,3,3,stride=3,padding=1)),
                    nn.Dropout(.2),
                    weight_norm(nn.Conv2d(3,96,3,stride=1,padding=1)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(96,96,3,stride=1,padding=1)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(96,96,3,stride=2,padding=1)),
                    nn.LeakyReLU(),

                    nn.Dropout(.5),
                    weight_norm(nn.Conv2d(96,192,3,stride=1,padding=1)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(192,192,3,stride=1,padding=1)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(192,192,3,stride=2,padding=1)),
                    nn.LeakyReLU(),
                    
                    nn.Dropout(.5),
                    weight_norm(nn.Conv2d(192,192,3,stride=1,padding=0)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(192,192,1,stride=1,padding=0)),
                    nn.LeakyReLU(),
                    weight_norm(nn.Conv2d(192,192,1,stride=1,padding=0)),
                    nn.LeakyReLU(),

                    # nn.AvgPool2d(6,stride=1),
                    nn.AdaptiveAvgPool2d(1),
                    nn.Flatten()
                )

            self.fc = weight_norm(nn.Linear(192,num_classes))
            
        def forward(self,x):
            inter_layer = self.net(x)
            logits = F.log_softmax(self.fc(inter_layer),dim=1)
            return logits
lr = 0.01
num_epochs = 50

classifier = Discriminator(100)

# %%
#from torchvision import models

# %%
'''
classifier = models.resnet50(pretrained=False)
classifier.fc = nn.Linear(2048, 100)

gpu_boole = torch.cuda.is_available()
if gpu_boole:
  model.cuda()
  '''
# Out:
# '\nclassifier = models.resnet50(pretrained=False)\nclassifier.fc = nn.Linear(2048, 100)\n\ngpu_boole = torch.cuda.is_available()\nif gpu_boole:\n  model.cuda()\n  '

# %%
#classifier = Classifier(image_reso = 96, filter_size = 5, dropout_rate = 0.2)

# %%
m2 = M2(latent_features = 512, classifier = classifier, path = "m2_stl10_0.1_50epoch_5.pth")

# %% [markdown]
# ### Structure of the M2 model: a convolutional variational autoencoder and a CNN classifier

# %%
m2.model
# Out:
# M2_base(
#   (encoder): Encoder(
#     (bottle): EncoderModule(
#       (conv): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (m1): EncoderModule(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (m2): EncoderModule(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (m3): EncoderModule(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (fc1): Linear(in_features=9316, out_features=512, bias=True)
#   (fc2): Linear(in_features=9316, out_features=512, bias=True)
#   (fc3): Linear(in_features=612, out_features=9216, bias=True)
#   (decoder): Decoder(
#     (m1): DecoderModule(
#       (convt): ConvTranspose2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU(inplace=True)
#     )
#     (m2): DecoderModule(
#       (convt): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(4, 4))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU(inplace=True)
#     )
#     (m3): DecoderModule(
#       (convt): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(4, 4))
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU(inplace=True)
#     )
#     (bottle): DecoderModule(
#       (convt): ConvTranspose2d(32, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bn): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): Sigmoid()
#     )
#   )
#   (classifier): Discriminator(
#     (net): Sequential(
#       (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (7): LeakyReLU(negative_slope=0.01)
#       (8): Dropout(p=0.5, inplace=False)
#       (9): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (10): LeakyReLU(negative_slope=0.01)
#       (11): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): LeakyReLU(negative_slope=0.01)
#       (13): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (14): LeakyReLU(negative_slope=0.01)
#       (15): Dropout(p=0.5, inplace=False)
#       (16): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1))
#       (17): LeakyReLU(negative_slope=0.01)
#       (18): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#       (19): LeakyReLU(negative_slope=0.01)
#       (20): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#       (21): LeakyReLU(negative_slope=0.01)
#       (22): AdaptiveAvgPool2d(output_size=1)
#       (23): Flatten(start_dim=1, end_dim=-1)
#     )
#     (fc): Linear(in_features=192, out_features=100, bias=True)
#   )
# )

# %% [markdown]
# ### Training the M2 model for 50 epochs:

# %%
#set alpha, hyperparameter for weighing the classifier loss
alpha = 0.1*len(train_loader.dataset)

# %%
#fit M2 model
#labeled_data_len is the number of labeled data in train+dev set: 450+1050
m2.fit(train_loader,dev_loader,100,alpha,labeled_data_len = 7000)
# Out:
# 0 375 Loss: -64158.160156
# 50 375 Loss: -91637.438496
# 100 375 Loss: -99846.367536
# 150 375 Loss: -104441.251992
# 200 375 Loss: -107884.501419
# 250 375 Loss: -110820.401628
# 300 375 Loss: -113254.212093
# 350 375 Loss: -115500.060820
# Epoch: 1, train loss: -116512.4474, training accuracy 0.0122, dev set accuracy 0.0090
# 0 375 Loss: -131515.000000
# 50 375 Loss: -133964.892463
# 100 375 Loss: -136234.912593
# 150 375 Loss: -138396.559706
# 200 375 Loss: -141431.287469
# 250 375 Loss: -146281.195219
# 300 375 Loss: -151316.829111
# 350 375 Loss: -156592.872730
# Epoch: 2, train loss: -158393.7778, training accuracy 0.0216, dev set accuracy 0.0180
# 0 375 Loss: -183224.843750
# 50 375 Loss: -195566.134498
# 100 375 Loss: -197889.176361
# 150 375 Loss: -201114.724441
# 200 375 Loss: -203684.087142
# 250 375 Loss: -206042.022535
# 300 375 Loss: -208781.096397
# 350 375 Loss: -211061.767094
# Epoch: 3, train loss: -212000.8136, training accuracy 0.0282, dev set accuracy 0.0310
# 0 375 Loss: -247946.125000
# 50 375 Loss: -229445.970895
# 100 375 Loss: -231413.882116
# 150 375 Loss: -234208.144040
# 200 375 Loss: -236811.076959
# 250 375 Loss: -238624.296252
# 300 375 Loss: -240778.351225
# 350 375 Loss: -242886.799457
# Epoch: 4, train loss: -243445.6998, training accuracy 0.0276, dev set accuracy 0.0370
# 0 375 Loss: -336544.812500
# 50 375 Loss: -263609.477328
# 100 375 Loss: -266197.105507
# 150 375 Loss: -267145.770178
# 200 375 Loss: -269197.676539
# 250 375 Loss: -271100.124377
# 300 375 Loss: -272152.107506
# 350 375 Loss: -274446.364049
# Epoch: 5, train loss: -274780.1410, training accuracy 0.0326, dev set accuracy 0.0350
# 0 375 Loss: -239127.375000
# 50 375 Loss: -291077.720588
# 100 375 Loss: -292942.801671
# 150 375 Loss: -294084.142384
# 200 375 Loss: -296722.937500
# 250 375 Loss: -298805.513135
# 300 375 Loss: -300142.533482
# 350 375 Loss: -302557.076656
# Epoch: 6, train loss: -303589.1672, training accuracy 0.0416, dev set accuracy 0.0485
# 0 375 Loss: -368403.500000
# 50 375 Loss: -326602.693321
# 100 375 Loss: -324792.943224
# 150 375 Loss: -330374.567363
# 200 375 Loss: -333263.201881
# 250 375 Loss: -334363.626556
# 300 375 Loss: -335147.717556
# 350 375 Loss: -335984.551594
# Epoch: 7, train loss: -336493.8885, training accuracy 0.0428, dev set accuracy 0.0570
# 150 375 Loss: -1438218.239238
# 200 375 Loss: -1437858.659204
# 250 375 Loss: -1438577.802291
# 300 375 Loss: -1436816.476744
# 350 375 Loss: -1436820.537393
# Epoch: 98, train loss: -1435731.5817, training accuracy 0.7042, dev set accuracy 0.1810
# 0 375 Loss: -1491537.500000
# 50 375 Loss: -1429928.600490
# 100 375 Loss: -1439554.748762
# 150 375 Loss: -1442779.628311
# 200 375 Loss: -1438570.611318
# 250 375 Loss: -1432930.307271
# 300 375 Loss: -1437887.621262
# 350 375 Loss: -1440724.088319
# Epoch: 99, train loss: -1437645.6593, training accuracy 0.7072, dev set accuracy 0.1805
# 0 375 Loss: -1426570.500000
# 50 375 Loss: -1427168.296569
# 100 375 Loss: -1441897.030941
# 150 375 Loss: -1448676.122517
# 200 375 Loss: -1433623.855721
# 250 375 Loss: -1433142.557271
# 300 375 Loss: -1435107.928156
# 350 375 Loss: -1435737.725427
# Epoch: 100, train loss: -1436292.7817, training accuracy 0.7088, dev set accuracy 0.1600

# %%
#best dev set accuracy 
m2.model.best_dev_accuracy
# Out:
# 0.1885

# %% [markdown]
# # Baseline Model:
# ### Only using the labeled data for supervised learning

# %%
#use the same dev set as M2
dev_ind_b = dev_ind
#training data is the same 1050 labeled data as M2
train_ind_b = (np.setdiff1d(labeled_ind, dev_ind))

# %%
len(dev_ind_b),len(train_ind_b)
# Out:
# (2000, 5000)

# %%
#prepare dataloader for pytroch
images_train_b = [data[i] for i in train_ind_b]
trainset_b = TorchInputData(images_train_b, labels[train_ind_b])
train_loader_b = tud.DataLoader(trainset_b, batch_size=50, shuffle=True)

# %%
images_dev_b = [data[i] for i in dev_ind_b]
devset_b = TorchInputData(images_dev_b, labels[dev_ind_b])
dev_loader_b = tud.DataLoader(devset_b, batch_size=50, shuffle=True)

# %%
from dcganbaseline_cnn_cifar100_cuda import BaselineConvNetdc

# %%
baseline = BaselineConvNetdc(96, path = "baseline_stl10_100epoch_5.pth")

# %%
from baseline_cnn_cifar100_cuda import BaselineConvNet

# %%
baseline2 = BaselineConvNet(96, path = "baseline2_stl10_100epoch_5.pth")

# %% [markdown]
# ### Structure of the baseline model: same as the classifier in the M2 model

# %%
baseline.model
# Out:
# TwoLayerConvNet(
#   (net): Sequential(
#     (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#     (1): Dropout(p=0.2, inplace=False)
#     (2): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): LeakyReLU(negative_slope=0.01)
#     (11): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): LeakyReLU(negative_slope=0.01)
#     (13): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): LeakyReLU(negative_slope=0.01)
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1))
#     (17): LeakyReLU(negative_slope=0.01)
#     (18): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (19): LeakyReLU(negative_slope=0.01)
#     (20): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (21): LeakyReLU(negative_slope=0.01)
#     (22): AdaptiveAvgPool2d(output_size=1)
#     (23): Flatten(start_dim=1, end_dim=-1)
#   )
#   (fc): Linear(in_features=192, out_features=100, bias=True)
# )

# %%
baseline2.model
# Out:
# TwoLayerConvNet(
#   (conv1_drop): Dropout2d(p=0.2, inplace=False)
#   (conv1): Conv2d(3, 10, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2_drop): Dropout2d(p=0.2, inplace=False)
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool): AvgPool2d(kernel_size=4, stride=4, padding=0)
#   (fc1): Linear(in_features=2880, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=100, bias=True)
# )

# %%
baseline.fit(train_loader_b,dev_loader_b)
baseline.train(50)
# Out:
# Train Epoch: 0 [0/5000 (0%)]	Loss: 4.605047
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Dev set: Average loss: 4.5218, Accuracy: 39/2000 (2%)
#
# Train Epoch: 1 [0/5000 (0%)]	Loss: 4.545575
#
# Dev set: Average loss: 4.3668, Accuracy: 51/2000 (3%)
#
# Train Epoch: 2 [0/5000 (0%)]	Loss: 4.209342
#
# Dev set: Average loss: 4.3289, Accuracy: 52/2000 (3%)
#
# Train Epoch: 3 [0/5000 (0%)]	Loss: 4.507625
#
# Dev set: Average loss: 4.2520, Accuracy: 61/2000 (3%)
#
# Train Epoch: 4 [0/5000 (0%)]	Loss: 4.215330
#
# Dev set: Average loss: 4.2114, Accuracy: 65/2000 (3%)
#
# Train Epoch: 5 [0/5000 (0%)]	Loss: 4.192078
#
# Dev set: Average loss: 4.1517, Accuracy: 86/2000 (4%)
#
# Train Epoch: 6 [0/5000 (0%)]	Loss: 4.000678
#
# Dev set: Average loss: 4.1676, Accuracy: 83/2000 (4%)
#
# Train Epoch: 7 [0/5000 (0%)]	Loss: 4.138805
#
# Dev set: Average loss: 4.0850, Accuracy: 111/2000 (6%)
#
# Train Epoch: 8 [0/5000 (0%)]	Loss: 4.081384
#
# Dev set: Average loss: 4.0910, Accuracy: 111/2000 (6%)
#
# Train Epoch: 9 [0/5000 (0%)]	Loss: 3.915862
#
# Dev set: Average loss: 4.0543, Accuracy: 120/2000 (6%)
#
# Train Epoch: 10 [0/5000 (0%)]	Loss: 3.801912
#
# Dev set: Average loss: 3.9685, Accuracy: 141/2000 (7%)
#
# Train Epoch: 11 [0/5000 (0%)]	Loss: 3.887221
#
# Dev set: Average loss: 3.9521, Accuracy: 147/2000 (7%)
#
# Train Epoch: 12 [0/5000 (0%)]	Loss: 3.724603
#
# Dev set: Average loss: 3.9226, Accuracy: 157/2000 (8%)
#
# Train Epoch: 13 [0/5000 (0%)]	Loss: 3.641272
#
# Dev set: Average loss: 3.9248, Accuracy: 155/2000 (8%)
#
# Train Epoch: 14 [0/5000 (0%)]	Loss: 3.847313
#
# Dev set: Average loss: 3.8859, Accuracy: 188/2000 (9%)
#
# Train Epoch: 15 [0/5000 (0%)]	Loss: 3.534865
#
# Dev set: Average loss: 3.8958, Accuracy: 137/2000 (7%)
#
# Train Epoch: 16 [0/5000 (0%)]	Loss: 3.771713
#
# Dev set: Average loss: 3.8295, Accuracy: 190/2000 (10%)
#
# Train Epoch: 17 [0/5000 (0%)]	Loss: 3.741431
#
# Dev set: Average loss: 3.7950, Accuracy: 207/2000 (10%)
#
# Train Epoch: 18 [0/5000 (0%)]	Loss: 3.473968
#
# Dev set: Average loss: 3.8069, Accuracy: 183/2000 (9%)
#
# Train Epoch: 19 [0/5000 (0%)]	Loss: 3.643364
#
# Dev set: Average loss: 3.7553, Accuracy: 229/2000 (11%)
#
# Train Epoch: 20 [0/5000 (0%)]	Loss: 3.426943
#
# Dev set: Average loss: 3.7659, Accuracy: 229/2000 (11%)
#
# Train Epoch: 21 [0/5000 (0%)]	Loss: 3.417284
#
# Dev set: Average loss: 3.8137, Accuracy: 216/2000 (11%)
#
# Train Epoch: 22 [0/5000 (0%)]	Loss: 3.704597
#
# Dev set: Average loss: 3.7270, Accuracy: 238/2000 (12%)
#
# Train Epoch: 23 [0/5000 (0%)]	Loss: 3.256935
#
# Dev set: Average loss: 3.7206, Accuracy: 242/2000 (12%)
#
# Train Epoch: 24 [0/5000 (0%)]	Loss: 3.115720
#
# Dev set: Average loss: 3.6750, Accuracy: 256/2000 (13%)
#
# Train Epoch: 25 [0/5000 (0%)]	Loss: 3.611658
#
# Dev set: Average loss: 3.7823, Accuracy: 246/2000 (12%)
#
# Train Epoch: 26 [0/5000 (0%)]	Loss: 3.317757
#
# Dev set: Average loss: 3.7408, Accuracy: 249/2000 (12%)
#
# Train Epoch: 27 [0/5000 (0%)]	Loss: 3.154170
#
# Dev set: Average loss: 3.7282, Accuracy: 264/2000 (13%)
#
# Train Epoch: 28 [0/5000 (0%)]	Loss: 3.158113
#
# Dev set: Average loss: 3.6916, Accuracy: 266/2000 (13%)
#
# Train Epoch: 29 [0/5000 (0%)]	Loss: 2.939416
#
# Dev set: Average loss: 3.7840, Accuracy: 277/2000 (14%)
#
# Train Epoch: 30 [0/5000 (0%)]	Loss: 3.041685
#
# Dev set: Average loss: 3.6878, Accuracy: 294/2000 (15%)
#
# Train Epoch: 31 [0/5000 (0%)]	Loss: 2.907361
#
# Dev set: Average loss: 3.7222, Accuracy: 272/2000 (14%)
#
# Train Epoch: 32 [0/5000 (0%)]	Loss: 2.734035
#
# Dev set: Average loss: 3.7852, Accuracy: 270/2000 (14%)
#
# Train Epoch: 33 [0/5000 (0%)]	Loss: 2.937271
#
# Dev set: Average loss: 3.8075, Accuracy: 284/2000 (14%)
#
# Train Epoch: 34 [0/5000 (0%)]	Loss: 3.064923
#
# Dev set: Average loss: 3.8998, Accuracy: 299/2000 (15%)
#
# Train Epoch: 35 [0/5000 (0%)]	Loss: 2.694665
#
# Dev set: Average loss: 3.7903, Accuracy: 293/2000 (15%)
#
# Train Epoch: 36 [0/5000 (0%)]	Loss: 2.793308
#
# Dev set: Average loss: 3.8280, Accuracy: 303/2000 (15%)
#
# Train Epoch: 37 [0/5000 (0%)]	Loss: 2.525846
#
# Dev set: Average loss: 3.9759, Accuracy: 310/2000 (16%)
#
# Train Epoch: 38 [0/5000 (0%)]	Loss: 2.568734
#
# Dev set: Average loss: 4.0598, Accuracy: 298/2000 (15%)
#
# Train Epoch: 39 [0/5000 (0%)]	Loss: 2.168459
#
# Dev set: Average loss: 4.0757, Accuracy: 281/2000 (14%)
#
# Train Epoch: 40 [0/5000 (0%)]	Loss: 2.555846
#
# Dev set: Average loss: 4.2917, Accuracy: 294/2000 (15%)
#
# Train Epoch: 41 [0/5000 (0%)]	Loss: 2.145456
#
# Dev set: Average loss: 4.3149, Accuracy: 311/2000 (16%)
#
# Train Epoch: 42 [0/5000 (0%)]	Loss: 2.203146
#
# Dev set: Average loss: 4.4259, Accuracy: 299/2000 (15%)
#
# Train Epoch: 43 [0/5000 (0%)]	Loss: 1.429030
#
# Dev set: Average loss: 4.6075, Accuracy: 303/2000 (15%)
#
# Train Epoch: 44 [0/5000 (0%)]	Loss: 2.094906
#
# Dev set: Average loss: 4.7799, Accuracy: 294/2000 (15%)
#
# Train Epoch: 45 [0/5000 (0%)]	Loss: 1.788283
#
# Dev set: Average loss: 5.0315, Accuracy: 294/2000 (15%)
#
# Train Epoch: 46 [0/5000 (0%)]	Loss: 1.821612
#
# Dev set: Average loss: 5.3549, Accuracy: 285/2000 (14%)
#
# Train Epoch: 47 [0/5000 (0%)]	Loss: 1.422109
#
# Dev set: Average loss: 5.2163, Accuracy: 285/2000 (14%)
#
# Train Epoch: 48 [0/5000 (0%)]	Loss: 1.329818
#
# Dev set: Average loss: 5.7768, Accuracy: 289/2000 (14%)
#
# Train Epoch: 49 [0/5000 (0%)]	Loss: 0.994546
#
# Dev set: Average loss: 5.8791, Accuracy: 275/2000 (14%)

# %%
baseline.model.best_dev_accuracy
# Out:
# 0.1555

# %%
baseline2.fit(train_loader_b,dev_loader_b)
baseline2.train(50)
# Out:
# Train Epoch: 0 [0/5000 (0%)]	Loss: 4.714299
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Dev set: Average loss: 4.5833, Accuracy: 32/2000 (2%)
#
# Train Epoch: 1 [0/5000 (0%)]	Loss: 4.556615
#
# Dev set: Average loss: 4.5237, Accuracy: 54/2000 (3%)
#
# Train Epoch: 2 [0/5000 (0%)]	Loss: 4.506165
#
# Dev set: Average loss: 4.4608, Accuracy: 75/2000 (4%)
#
# Train Epoch: 3 [0/5000 (0%)]	Loss: 4.420135
#
# Dev set: Average loss: 4.3779, Accuracy: 89/2000 (4%)
#
# Train Epoch: 4 [0/5000 (0%)]	Loss: 4.258813
#
# Dev set: Average loss: 4.3202, Accuracy: 130/2000 (6%)
#
# Train Epoch: 5 [0/5000 (0%)]	Loss: 3.946921
#
# Dev set: Average loss: 4.2249, Accuracy: 148/2000 (7%)
#
# Train Epoch: 6 [0/5000 (0%)]	Loss: 3.888243
#
# Dev set: Average loss: 4.1647, Accuracy: 171/2000 (9%)
#
# Train Epoch: 7 [0/5000 (0%)]	Loss: 3.898630
#
# Dev set: Average loss: 4.0813, Accuracy: 185/2000 (9%)
#
# Train Epoch: 8 [0/5000 (0%)]	Loss: 3.890671
#
# Dev set: Average loss: 4.0554, Accuracy: 214/2000 (11%)
#
# Train Epoch: 9 [0/5000 (0%)]	Loss: 3.323659
#
# Dev set: Average loss: 4.0003, Accuracy: 213/2000 (11%)
#
# Train Epoch: 10 [0/5000 (0%)]	Loss: 3.180380
#
# Dev set: Average loss: 3.9937, Accuracy: 222/2000 (11%)
#
# Train Epoch: 11 [0/5000 (0%)]	Loss: 3.038353
#
# Dev set: Average loss: 4.0333, Accuracy: 214/2000 (11%)
#
# Train Epoch: 12 [0/5000 (0%)]	Loss: 3.397305
#
# Dev set: Average loss: 3.9935, Accuracy: 240/2000 (12%)
#
# Train Epoch: 13 [0/5000 (0%)]	Loss: 3.434601
#
# Dev set: Average loss: 4.0163, Accuracy: 256/2000 (13%)
#
# Train Epoch: 14 [0/5000 (0%)]	Loss: 3.038390
#
# Dev set: Average loss: 3.9799, Accuracy: 250/2000 (12%)
#
# Train Epoch: 15 [0/5000 (0%)]	Loss: 2.988076
#
# Dev set: Average loss: 4.0277, Accuracy: 235/2000 (12%)
#
# Train Epoch: 16 [0/5000 (0%)]	Loss: 2.576406
#
# Dev set: Average loss: 4.2108, Accuracy: 229/2000 (11%)
#
# Train Epoch: 17 [0/5000 (0%)]	Loss: 3.086461
#
# Dev set: Average loss: 4.1280, Accuracy: 243/2000 (12%)
#
# Train Epoch: 18 [0/5000 (0%)]	Loss: 2.242234
#
# Dev set: Average loss: 4.1937, Accuracy: 256/2000 (13%)
#
# Train Epoch: 19 [0/5000 (0%)]	Loss: 2.310193
#
# Dev set: Average loss: 4.3331, Accuracy: 267/2000 (13%)
#
# Train Epoch: 20 [0/5000 (0%)]	Loss: 2.408726
#
# Dev set: Average loss: 4.2989, Accuracy: 250/2000 (12%)
#
# Train Epoch: 21 [0/5000 (0%)]	Loss: 2.213075
#
# Dev set: Average loss: 4.4842, Accuracy: 275/2000 (14%)
#
# Train Epoch: 22 [0/5000 (0%)]	Loss: 2.127616
#
# Dev set: Average loss: 4.5296, Accuracy: 253/2000 (13%)
#
# Train Epoch: 23 [0/5000 (0%)]	Loss: 2.055219
#
# Dev set: Average loss: 4.7461, Accuracy: 243/2000 (12%)
#
# Train Epoch: 24 [0/5000 (0%)]	Loss: 2.457796
#
# Dev set: Average loss: 4.9422, Accuracy: 277/2000 (14%)
#
# Train Epoch: 25 [0/5000 (0%)]	Loss: 1.813029
#
# Dev set: Average loss: 4.9785, Accuracy: 275/2000 (14%)
#
# Train Epoch: 26 [0/5000 (0%)]	Loss: 1.625394
#
# Dev set: Average loss: 5.1288, Accuracy: 275/2000 (14%)
#
# Train Epoch: 27 [0/5000 (0%)]	Loss: 1.524548
#
# Dev set: Average loss: 5.4903, Accuracy: 244/2000 (12%)
#
# Train Epoch: 28 [0/5000 (0%)]	Loss: 1.288462
#
# Dev set: Average loss: 5.8823, Accuracy: 253/2000 (13%)
#
# Train Epoch: 29 [0/5000 (0%)]	Loss: 1.209864
#
# Dev set: Average loss: 6.0748, Accuracy: 254/2000 (13%)
#
# Train Epoch: 30 [0/5000 (0%)]	Loss: 1.345727
#
# Dev set: Average loss: 6.1656, Accuracy: 267/2000 (13%)
#
# Train Epoch: 31 [0/5000 (0%)]	Loss: 0.849575
#
# Dev set: Average loss: 6.7480, Accuracy: 242/2000 (12%)
#
# Train Epoch: 32 [0/5000 (0%)]	Loss: 1.016925
#
# Dev set: Average loss: 6.8119, Accuracy: 226/2000 (11%)
#
# Train Epoch: 33 [0/5000 (0%)]	Loss: 0.475780
#
# Dev set: Average loss: 7.3216, Accuracy: 241/2000 (12%)
#
# Train Epoch: 34 [0/5000 (0%)]	Loss: 0.695706
#
# Dev set: Average loss: 7.6976, Accuracy: 250/2000 (12%)
#
# Train Epoch: 35 [0/5000 (0%)]	Loss: 0.632972
#
# Dev set: Average loss: 7.7051, Accuracy: 251/2000 (13%)
#
# Train Epoch: 36 [0/5000 (0%)]	Loss: 0.467270
#
# Dev set: Average loss: 8.5188, Accuracy: 223/2000 (11%)
#
# Train Epoch: 37 [0/5000 (0%)]	Loss: 0.549698
#
# Dev set: Average loss: 8.4082, Accuracy: 242/2000 (12%)
#
# Train Epoch: 38 [0/5000 (0%)]	Loss: 0.351275
#
# Dev set: Average loss: 9.1292, Accuracy: 223/2000 (11%)
#
# Train Epoch: 39 [0/5000 (0%)]	Loss: 0.572802
#
# Dev set: Average loss: 9.4933, Accuracy: 246/2000 (12%)
#
# Train Epoch: 40 [0/5000 (0%)]	Loss: 0.252046
#
# Dev set: Average loss: 9.7518, Accuracy: 249/2000 (12%)
#
# Train Epoch: 41 [0/5000 (0%)]	Loss: 0.114821
#
# Dev set: Average loss: 10.2107, Accuracy: 219/2000 (11%)
#
# Train Epoch: 42 [0/5000 (0%)]	Loss: 0.369047
#
# Dev set: Average loss: 10.7495, Accuracy: 241/2000 (12%)
#
# Train Epoch: 43 [0/5000 (0%)]	Loss: 0.186252
#
# Dev set: Average loss: 11.6053, Accuracy: 227/2000 (11%)
#
# Train Epoch: 44 [0/5000 (0%)]	Loss: 0.084833
#
# Dev set: Average loss: 11.5278, Accuracy: 228/2000 (11%)
#
# Train Epoch: 45 [0/5000 (0%)]	Loss: 0.168423
#
# Dev set: Average loss: 11.9182, Accuracy: 229/2000 (11%)
#
# Train Epoch: 46 [0/5000 (0%)]	Loss: 0.284876
#
# Dev set: Average loss: 11.2129, Accuracy: 230/2000 (12%)
#
# Train Epoch: 47 [0/5000 (0%)]	Loss: 0.134283
#
# Dev set: Average loss: 12.3733, Accuracy: 226/2000 (11%)
#
# Train Epoch: 48 [0/5000 (0%)]	Loss: 0.066181
#
# Dev set: Average loss: 12.6075, Accuracy: 236/2000 (12%)
#
# Train Epoch: 49 [0/5000 (0%)]	Loss: 0.034067
#
# Dev set: Average loss: 12.5155, Accuracy: 234/2000 (12%)

# %%
#best dev set accuracy 
baseline2.model.best_dev_accuracy
# Out:
# 0.1385

# %% [markdown]
# # Test Set Performance:
# ### The M2 model successfully increase the accuracy of the classifier

# %%
#The testset dataloader
testset_loader = torch.utils.data.DataLoader(test, batch_size=1000, shuffle=True, num_workers=0)

# %%
conf_b, acc_b = baseline2.test(testset_loader,path = "baseline2_stl10_100epoch_5.pth",return_confusion_matrix = True)
# Out:
# Test set: Accuracy: 1354/10000 (14%)

# %%
conf_b, acc_b = baseline.test(testset_loader,path = "baseline_stl10_100epoch_5.pth",return_confusion_matrix = True)
# Out:
# Test set: Accuracy: 1576/10000 (16%)

# %%
conf, acc = m2.test(testset_loader,path = "m2_stl10_0.1_50epoch_5.pth",return_confusion_matrix = True)
# Out:
# Test set: Accuracy: 1894/10000 (19%)
